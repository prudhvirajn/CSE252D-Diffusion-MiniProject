# %%
from diffusers import DDPMPipeline

image_pipe = DDPMPipeline.from_pretrained("google/ddpm-church-256")
image_pipe.to("cuda")

images = image_pipe().images
# Out:
# Downloading (…)ain/model_index.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors not found
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading (…)619b9e04/config.json:   0%|          | 0.00/790 [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# Downloading (…)on_pytorch_model.bin:   0%|          | 0.00/455M [00:00<?, ?B/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8C0A468640>
